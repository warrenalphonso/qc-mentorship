# %%
from qutip import *
import numpy as np
import matplotlib.pyplot as plt

# %%
b = Bloch()
# I can customize font_color, font_size, frame_alpha (transparency), 
# frame_color, frame_width, point_color, sphere_alpha (sphere transparency), 
# fizsize, and many more. 
b.show()

# Functions for Bloch instance: 
# add_annotation: add text to a qubit state/vector 
# add_points 
# add_states 
# add_vectors 
# clear 
# make_sphere 
# render 
# save 
# set_label_convention 
# show 
# vector_mutation, style, width

# %%
b.clear()
b.add_points([1,1,1])
b.show()

# %%
from qutip.qip.circuit import QubitCircuit, Gate
qc = QubitCircuit(N=1)
qc.add_gate(Gate(name='SNOT', targets=1))
